# %% [markdown]
# # Home Price Prediction Models

# %% [markdown]
# ## Working with Home Price Data and Predicting House Prices Using Different Models.
# 1. Data importing
# 2. General Look-up
# 3. Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
import sklearn.metrics
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")


X = pd.read_csv('./train.csv', index_col='Id')
X_test_full = pd.read_csv('./test.csv', index_col='Id')
print(X.shape,X_test_full.shape)
display(X.head())
display(X_test_full.head())
# Out:
# (1460, 80) (1459, 79)
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461         NaN       0       6    2010        WD         Normal
# 1462        Gar2   12500       6    2010        WD         Normal
# 1463         NaN       0       3    2010        WD         Normal
# 1464         NaN       0       6    2010        WD         Normal
# 1465         NaN       0       1    2010        WD         Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# Deleting the rows where the target is missing, if the target is missing the feature data is of no use and adding a mean value or leaving it blank it just going to mess with the data later on.

# %%
# Remove rows with missing target, separate target from predictors
X.dropna(axis=0, subset=['SalePrice'], inplace=True)
y = X.SalePrice              
X.drop(['SalePrice'], axis=1, inplace=True)

# %% [markdown]
# Dividing the data into test and train

# %%
# Break off validation set from training data
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X, y, train_size=0.8,random_state=0)

# %% [markdown]
# ##### Dealing with Categorical Values | we will be adding a pipeline to make the Data Clean Up better

# %%
low_cardinality_cols = [cname for cname in X_train_full.columns if X_train_full[cname].nunique() < 10 and  X_train_full[cname].dtype == "object"]
high_cardinality_cols =[cname for cname in X_train_full.columns if X_train_full[cname].nunique() > 10 and  X_train_full[cname].dtype == "object"]
print(low_cardinality_cols,high_cardinality_cols)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'] ['Neighborhood', 'Exterior1st', 'Exterior2nd']

# %%
for x in high_cardinality_cols:
    print(f"{x} : length {X[x].nunique()}")
# Out:
# Neighborhood : length 25
# Exterior1st : length 15
# Exterior2nd : length 16

# %% [markdown]
# ##### Dealing with Numerical Values | we will be adding a pipeline to make the Data Clean Up better

# %%
numeric_cols = [cname for cname in X_train_full.columns if X_train_full[cname].dtype in ['int64', 'float64']]
print(numeric_cols,"\n",len(numeric_cols))
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
#  36

# %%
nulls = X.isna().sum()
nulls = { i:x for i,x in zip(nulls.index,nulls) if x> 1}
for i,x in nulls.items():
    print(f"column {i} \thas {x} missing values")
# Out:
# column LotFrontage 	has 259 missing values
# column Alley 	has 1369 missing values
# column MasVnrType 	has 8 missing values
# column MasVnrArea 	has 8 missing values
# column BsmtQual 	has 37 missing values
# column BsmtCond 	has 37 missing values
# column BsmtExposure 	has 38 missing values
# column BsmtFinType1 	has 37 missing values
# column BsmtFinType2 	has 38 missing values
# column FireplaceQu 	has 690 missing values
# column GarageType 	has 81 missing values
# column GarageYrBlt 	has 81 missing values
# column GarageFinish 	has 81 missing values
# column GarageQual 	has 81 missing values
# column GarageCond 	has 81 missing values
# column PoolQC 	has 1453 missing values
# column Fence 	has 1179 missing values
# column MiscFeature 	has 1406 missing values

# %%
missing = pd.DataFrame((X.isnull().sum())*100/X.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
my_cols = low_cardinality_cols + high_cardinality_cols + numeric_cols
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numeric_cols),
        ('low_card', categorical_transformer, low_cardinality_cols),

    ])

# %% [markdown]
# Lets start with a simple test using RandomForestRegressor and we will improve our model(s) from there

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100, random_state=0)

# %%
from sklearn.metrics import mean_absolute_error

# Bundle preprocessing and modeling code in a pipeline
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model)
                             ])

# Preprocessing of training data, fit model 
my_pipeline.fit(X_train, y_train)

# Preprocessing of validation data, get predictions
preds = my_pipeline.predict(X_valid)

# Evaluate the model
score = mean_absolute_error(y_valid, preds)
print('MAE:', score)
# Out:
# MAE: 17861.780102739725

# %% [markdown]
# As we can see that 17861 is a good score but we can do alot better than this. lets start by finding out what features are working the most and which ones are impeding our progress.

# %%
corr = X.corr()
corr.style.background_gradient(cmap="autumn")
# Out:
# <style type="text/css">
# #T_c4199_row0_col0, #T_c4199_row1_col1, #T_c4199_row2_col2, #T_c4199_row3_col3, #T_c4199_row4_col4, #T_c4199_row5_col5, #T_c4199_row6_col6, #T_c4199_row7_col7, #T_c4199_row8_col8, #T_c4199_row9_col9, #T_c4199_row10_col10, #T_c4199_row11_col11, #T_c4199_row12_col12, #T_c4199_row13_col13, #T_c4199_row14_col14, #T_c4199_row15_col15, #T_c4199_row16_col16, #T_c4199_row17_col17, #T_c4199_row18_col18, #T_c4199_row19_col19, #T_c4199_row20_col20, #T_c4199_row21_col21, #T_c4199_row22_col22, #T_c4199_row23_col23, #T_c4199_row24_col24, #T_c4199_row25_col25, #T_c4199_row26_col26, #T_c4199_row27_col27, #T_c4199_row28_col28, #T_c4199_row29_col29, #T_c4199_row30_col30, #T_c4199_row31_col31, #T_c4199_row32_col32, #T_c4199_row33_col33, #T_c4199_row34_col34, #T_c4199_row35_col35 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_c4199_row0_col1, #T_c4199_row0_col2, #T_c4199_row0_col11, #T_c4199_row0_col12, #T_c4199_row0_col30, #T_c4199_row1_col0, #T_c4199_row3_col21, #T_c4199_row4_col7, #T_c4199_row4_col15, #T_c4199_row4_col18, #T_c4199_row4_col22, #T_c4199_row4_col24, #T_c4199_row4_col25, #T_c4199_row4_col26, #T_c4199_row5_col4, #T_c4199_row5_col14, #T_c4199_row5_col29, #T_c4199_row8_col10, #T_c4199_row10_col8, #T_c4199_row10_col9, #T_c4199_row10_col16, #T_c4199_row12_col13, #T_c4199_row12_col19, #T_c4199_row16_col17, #T_c4199_row16_col20, #T_c4199_row21_col3, #T_c4199_row21_col23, #T_c4199_row25_col33, #T_c4199_row29_col5, #T_c4199_row29_col6, #T_c4199_row29_col27, #T_c4199_row29_col28, #T_c4199_row29_col31, #T_c4199_row34_col35, #T_c4199_row35_col32, #T_c4199_row35_col34 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col3, #T_c4199_row7_col4, #T_c4199_row10_col21, #T_c4199_row12_col32, #T_c4199_row30_col3, #T_c4199_row33_col13, #T_c4199_row34_col6, #T_c4199_row35_col11, #T_c4199_row35_col21 {
#   background-color: #ff2e00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col4, #T_c4199_row1_col4, #T_c4199_row8_col0, #T_c4199_row18_col19, #T_c4199_row19_col4, #T_c4199_row20_col2, #T_c4199_row20_col5, #T_c4199_row20_col25, #T_c4199_row24_col13, #T_c4199_row27_col9 {
#   background-color: #ff3a00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col5, #T_c4199_row0_col16, #T_c4199_row1_col24, #T_c4199_row4_col8, #T_c4199_row5_col0, #T_c4199_row9_col8, #T_c4199_row13_col24, #T_c4199_row22_col28, #T_c4199_row30_col16 {
#   background-color: #ff4c00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col6, #T_c4199_row3_col29, #T_c4199_row14_col15, #T_c4199_row18_col29, #T_c4199_row20_col24, #T_c4199_row28_col2, #T_c4199_row34_col13 {
#   background-color: #ff3200;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col7, #T_c4199_row1_col35, #T_c4199_row3_col31, #T_c4199_row5_col2, #T_c4199_row6_col2, #T_c4199_row7_col31, #T_c4199_row8_col31, #T_c4199_row13_col32, #T_c4199_row17_col23, #T_c4199_row19_col2, #T_c4199_row22_col32, #T_c4199_row27_col14, #T_c4199_row30_col21, #T_c4199_row31_col35, #T_c4199_row32_col22, #T_c4199_row34_col14 {
#   background-color: #ff2200;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col8, #T_c4199_row1_col7, #T_c4199_row6_col13, #T_c4199_row13_col23, #T_c4199_row20_col4, #T_c4199_row22_col29, #T_c4199_row24_col19, #T_c4199_row26_col13, #T_c4199_row32_col0, #T_c4199_row32_col5, #T_c4199_row35_col1 {
#   background-color: #ff4800;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col9, #T_c4199_row2_col19, #T_c4199_row3_col32, #T_c4199_row4_col2, #T_c4199_row6_col17, #T_c4199_row7_col35, #T_c4199_row9_col20, #T_c4199_row9_col21, #T_c4199_row10_col2, #T_c4199_row16_col21, #T_c4199_row16_col32, #T_c4199_row19_col17, #T_c4199_row19_col34, #T_c4199_row19_col35, #T_c4199_row20_col31, #T_c4199_row29_col35, #T_c4199_row30_col23, #T_c4199_row33_col25, #T_c4199_row34_col15 {
#   background-color: #ff1e00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col10, #T_c4199_row1_col6, #T_c4199_row1_col13, #T_c4199_row2_col20, #T_c4199_row4_col0, #T_c4199_row4_col1, #T_c4199_row6_col22, #T_c4199_row32_col13 {
#   background-color: #ff3c00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col13, #T_c4199_row15_col5, #T_c4199_row18_col1, #T_c4199_row22_col11, #T_c4199_row22_col26, #T_c4199_row26_col16, #T_c4199_row32_col8 {
#   background-color: #ff6c00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col14, #T_c4199_row4_col13, #T_c4199_row13_col27, #T_c4199_row17_col11, #T_c4199_row17_col16, #T_c4199_row24_col22, #T_c4199_row30_col18, #T_c4199_row32_col20, #T_c4199_row32_col23, #T_c4199_row35_col6 {
#   background-color: #ff3100;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col15, #T_c4199_row4_col20, #T_c4199_row12_col14, #T_c4199_row19_col31, #T_c4199_row22_col9, #T_c4199_row25_col9, #T_c4199_row30_col35, #T_c4199_row32_col21, #T_c4199_row32_col28 {
#   background-color: #ff2400;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col17, #T_c4199_row2_col34, #T_c4199_row4_col31, #T_c4199_row11_col14, #T_c4199_row11_col17, #T_c4199_row14_col2, #T_c4199_row20_col6, #T_c4199_row24_col35, #T_c4199_row27_col32, #T_c4199_row32_col19, #T_c4199_row33_col3 {
#   background-color: #ff2000;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col18, #T_c4199_row0_col29, #T_c4199_row6_col7, #T_c4199_row6_col19, #T_c4199_row8_col6, #T_c4199_row17_col29, #T_c4199_row27_col0, #T_c4199_row27_col2, #T_c4199_row27_col4, #T_c4199_row29_col0, #T_c4199_row31_col12, #T_c4199_row32_col4, #T_c4199_row33_col0, #T_c4199_row34_col4, #T_c4199_row35_col29 {
#   background-color: #ff4500;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col19, #T_c4199_row2_col9, #T_c4199_row2_col27, #T_c4199_row14_col16, #T_c4199_row16_col6, #T_c4199_row20_col0, #T_c4199_row29_col8, #T_c4199_row29_col16, #T_c4199_row30_col24, #T_c4199_row35_col0 {
#   background-color: #ff4300;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col20, #T_c4199_row7_col9, #T_c4199_row8_col19, #T_c4199_row14_col6, #T_c4199_row15_col17, #T_c4199_row17_col26, #T_c4199_row18_col9, #T_c4199_row18_col35, #T_c4199_row25_col17, #T_c4199_row25_col21, #T_c4199_row30_col20, #T_c4199_row31_col21, #T_c4199_row31_col22, #T_c4199_row33_col23, #T_c4199_row35_col2 {
#   background-color: #ff1c00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col21, #T_c4199_row5_col7, #T_c4199_row6_col12, #T_c4199_row7_col18, #T_c4199_row19_col24, #T_c4199_row23_col16, #T_c4199_row28_col11 {
#   background-color: #ff6400;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col22, #T_c4199_row10_col35, #T_c4199_row13_col9, #T_c4199_row14_col23, #T_c4199_row25_col35, #T_c4199_row30_col15 {
#   background-color: #ff1700;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col23, #T_c4199_row4_col30, #T_c4199_row5_col20, #T_c4199_row7_col32, #T_c4199_row8_col30, #T_c4199_row18_col31, #T_c4199_row32_col33, #T_c4199_row33_col28, #T_c4199_row34_col30 {
#   background-color: #ff1100;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col24, #T_c4199_row5_col27, #T_c4199_row8_col2, #T_c4199_row11_col28, #T_c4199_row13_col25, #T_c4199_row14_col0, #T_c4199_row20_col19, #T_c4199_row20_col29, #T_c4199_row24_col27, #T_c4199_row26_col27 {
#   background-color: #ff4f00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col25, #T_c4199_row1_col17, #T_c4199_row3_col9, #T_c4199_row4_col34, #T_c4199_row7_col21, #T_c4199_row7_col34, #T_c4199_row9_col25, #T_c4199_row14_col17, #T_c4199_row17_col3, #T_c4199_row17_col21, #T_c4199_row20_col32, #T_c4199_row24_col14, #T_c4199_row25_col31, #T_c4199_row26_col31, #T_c4199_row29_col17, #T_c4199_row32_col7, #T_c4199_row32_col31, #T_c4199_row33_col17, #T_c4199_row33_col34, #T_c4199_row34_col2, #T_c4199_row35_col25 {
#   background-color: #ff1f00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col26, #T_c4199_row1_col33, #T_c4199_row8_col33, #T_c4199_row9_col33, #T_c4199_row10_col17, #T_c4199_row21_col19, #T_c4199_row31_col27, #T_c4199_row35_col33 {
#   background-color: #ff0b00;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col27, #T_c4199_row8_col14, #T_c4199_row9_col18, #T_c4199_row14_col31, #T_c4199_row16_col31, #T_c4199_row19_col21, #T_c4199_row21_col33, #T_c4199_row24_col2, #T_c4199_row24_col9, #T_c4199_row26_col14, #T_c4199_row26_col21, #T_c4199_row32_col34, #T_c4199_row34_col19, #T_c4199_row34_col31, #T_c4199_row35_col19, #T_c4199_row35_col20 {
#   background-color: #ff1900;
#   color: #f1f1f1;
# }
# #T_c4199_row0_col28, #T_c4199_row4_col21, #T_c41
